# %%
# To test my class on various sites
# Because thisi reddit: https://www.reddit.com/r/learnmachinelearning/comments/1dfe74w/best_offline_resources_for_learning/

from DestroyPrettyPage import DestroyPrettyPage

url = 'https://course.fast.ai/'

dpp = DestroyPrettyPage(url)
print(dpp.rules)
# Out:
# Not supposed to do this:
# Invalid URL. Initiating development mode.
# host is:test.html
# **********
#
#
#
#
#
#
# 0) nothing to see 1	-	nowhere1
# 1) nothing to see 2	-	nowhere2
# 2) nothing to see 3	-	nowhere3
# 3) nothing to see 4	-	nowhere4
# 4) nothing to see 5	-	nowhere5
# getting content
# here
# <h1>International Flights</h1>
# content:  <h1>International Flights</h1>
# Error parsing the website
# URL: file://test.html. Error: Cannot replace one element with another when the element to be replaced is not part of a tree.
# host is:course.fast.ai
# **********
#
#
#
#
#
#
# <class 'DestroyPrettyPage.RuleType'>
# c:\Users\haaik\Documents\Cs\overrit\DestroyPrettyPage.py:229: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# ...

# %%
print(dpp.links)
# print(dpp.getContent(dpp.soup))
print(dpp.html)
# Out:
# []
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="quarto-1.4.451" name="generator"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
#   <meta content="A free course designed for people with some coding experience, who want to learn how to apply deep learning and machine learning to practical problems." name="description"/>
#   <title>
#    Practical Deep Learning for Coders - Practical Deep Learning
#   </title>
#   <style>
#    code{white-space: pre-wrap;}
# span.smallcaps{font-variant: small-caps;}
# div.columns{display: flex; gap: min(4vw, 1.5em);}
# div.column{flex: auto; overflow-x: auto;}
# div.hanging-indent{margin-left: 1.5em; text-indent: -1.5em;}
# ul.task-list{list-style: none;}
# ul.task-list li input[type="checkbox"] {
#   width: 0.8em;
# ...
